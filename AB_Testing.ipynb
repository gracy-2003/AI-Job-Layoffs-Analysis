# %%
pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

from scipy.stats import ttest_ind
from scipy.stats import chi2_contingency

# %%
df = pd.read_csv("AI_Job_Layoffs_Cleaned.csv")

# %%
df.isnull().sum()
# Out:
# event_id                        0
# date                          728
# year                            0
# quarter                         0
# month                           0
# company_name                    0
# industry                        0
# region                          0
# country                         0
# company_size                    0
# total_workforce_before          0
# headcount_cut                   0
# workforce_after                 0
# pct_workforce_cut               0
# role_category                   0
# seniority_level                 0
# ai_exposure_score               0
# stated_reason                   0
# ai_cited_as_reason              0
# revenue_growth_yoy_pct          0
# ai_capex_change_yoy_pct         0
# stock_price_change_30d_pct      0
# shifted_staff_to_ai_roles       0
# source_type                     0
# dtype: int64

# %%
group_ai = df[df['ai_cited_as_reason'] == 'Yes']['revenue_growth_yoy_pct']

group_non_ai = df[df['ai_cited_as_reason'] == 'No']['revenue_growth_yoy_pct']

t_stat, p_value = ttest_ind(group_ai, group_non_ai, nan_policy='omit')

print("T-Statistic :", t_stat)
print("P-Value :", p_value)

if p_value < 0.05:
    print("Reject H0")
    print("Revenue growth differs significantly.")
else:
    print("Fail to Reject H0")
    print("No significant difference.")
# Out:
# T-Statistic : 15.51216466565403
# P-Value : 4.647537382991581e-50
# Reject H0
# Revenue growth differs significantly.

# %%
group_ai = df[df['ai_cited_as_reason'] == 'Yes']['ai_capex_change_yoy_pct']

group_non_ai = df[df['ai_cited_as_reason'] == 'No']['ai_capex_change_yoy_pct']

t_stat, p_value = ttest_ind(group_ai, group_non_ai, nan_policy='omit')

print("T-Statistic :", t_stat)
print("P-Value :", p_value)

if p_value < 0.05:
    print("Reject H0")
    print("AI Capex differs significantly.")
else:
    print("Fail to Reject H0")
    print("No significant difference.")
# Out:
# T-Statistic : 24.907018078028607
# P-Value : 5.910841039955724e-113
# Reject H0
# AI Capex differs significantly.

# %%
group_ai = df[df['ai_cited_as_reason'] == 'Yes']['pct_workforce_cut']

group_non_ai = df[df['ai_cited_as_reason'] == 'No']['pct_workforce_cut']

t_stat, p_value = ttest_ind(group_ai, group_non_ai, nan_policy='omit')

print("T-Statistic :", t_stat)
print("P-Value :", p_value)

if p_value < 0.05:
    print("Reject H0")
    print("Workforce reduction differs significantly.")
else:
    print("Fail to Reject H0")
    print("No significant difference.")
# Out:
# T-Statistic : 0.773661578436745
# P-Value : 0.43926659921560507
# Fail to Reject H0
# No significant difference.

# %%
group_ai = df[df['ai_cited_as_reason'] == 'Yes']['stock_price_change_30d_pct']

group_non_ai = df[df['ai_cited_as_reason'] == 'No']['stock_price_change_30d_pct']

t_stat, p_value = ttest_ind(group_ai, group_non_ai, nan_policy='omit')

print("T-Statistic :", t_stat)
print("P-Value :", p_value)

if p_value < 0.05:
    print("Reject H0")
    print("Stock price changes differ significantly.")
else:
    print("Fail to Reject H0")
    print("No significant difference.")
# Out:
# T-Statistic : 7.578707356831834
# P-Value : 6.460015299884402e-14
# Reject H0
# Stock price changes differ significantly.

# %%
table = pd.crosstab(df['industry'], df['ai_cited_as_reason'])

chi2, p_value, dof, expected = chi2_contingency(table)

print("Chi-Square :", chi2)
print("P-Value :", p_value)

if p_value < 0.05:
    print("Reject H0")
    print("Industry and AI citation are associated.")
else:
    print("Fail to Reject H0")
    print("No significant association.")
# Out:
# Chi-Square : 27.189842750679503
# P-Value : 0.004301229513786754
# Reject H0
# Industry and AI citation are associated.

# %%
table = pd.crosstab(df['company_size'], df['ai_cited_as_reason'])

chi2, p_value, dof, expected = chi2_contingency(table)

print("Chi-Square :", chi2)
print("P-Value :", p_value)

if p_value < 0.05:
    print("Reject H0")
    print("Company size and AI citation are associated.")
else:
    print("Fail to Reject H0")
    print("No significant association.")
# Out:
# Chi-Square : 1.9741967814793862
# P-Value : 0.5777794950940529
# Fail to Reject H0
# No significant association.

# %%
table = pd.crosstab(df['seniority_level'], df['ai_cited_as_reason'])

chi2, p_value, dof, expected = chi2_contingency(table)

print("Chi-Square :", chi2)
print("P-Value :", p_value)

if p_value < 0.05:
    print("Reject H0")
    print("Seniority level and AI citation are associated.")
else:
    print("Fail to Reject H0")
    print("No significant association.")
# Out:
# Chi-Square : 6.637814057826514
# P-Value : 0.08438306380515695
# Fail to Reject H0
# No significant association.

# %%
table = pd.crosstab(df['role_category'], df['ai_cited_as_reason'])

chi2, p_value, dof, expected = chi2_contingency(table)

print("Chi-Square :", chi2)
print("P-Value :", p_value)

if p_value < 0.05:
    print("Reject H0")
    print("Role category and AI citation are associated.")
else:
    print("Fail to Reject H0")
    print("No significant association.")
# Out:
# Chi-Square : 34.80375823508356
# P-Value : 0.0009074588593363357
# Reject H0
# Role category and AI citation are associated.

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\gracy

# %%
import os

downloads_path = os.path.join(os.path.expanduser("~"), "Downloads")

df.to_csv(os.path.join(downloads_path, "AI_Job_Layoffs_Cleaned_AB_Testing.csv"), index=False)

print("File saved successfully!")
# Out:
# File saved successfully!
